# %%
import numpy as np
import matplotlib.pyplot as plt, mpld3
import pandas as pd
import plotly.plotly as py
from plotly.graph_objs import *
# %matplotlib inline

# %%
import block_handler
import plot_chunk

# %% [markdown]
# #  Minepath Eval

# %%
world = block_handler.load_world('/Users/ryanlambert/Desktop/MinecraftLandGenerator/world')

# %%
#print world.get_nbt(-9,-46)['Level']['Sections'][0]['Blocks']

# %%
world.get_boundingbox()
# Out:
# BoundingBox(-27,35,None,None,-30,32)

# %% [markdown]
# ### Path Type: Straight Path, 1x2 every 10th block spacing

# %%
one_by_two_10space = []
x_spacing = 10
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, x_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                one_by_two_10space.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in one_by_two_10space]
    zs = [j[1] for j in one_by_two_10space]
    ys = [k[2] for k in one_by_two_10space]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    print "keyerror"
    pass

one_by_two_10space_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}

blocks, one_by_two_10space_absolute_path = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=one_by_two_10space,
    ore_count=one_by_two_10space_ore_filter,
    world=world)

ore_counts = pd.DataFrame([one_by_two_10space_ore_filter], index=['one_by_two_10space'])
one_by_two_10space_efficiency = ore_counts / len(one_by_two_10space_absolute_path) * 100
one_by_two_10space_efficiency
print len(blocks)
## Reset ore_filter before running again
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks = pd.DataFrame(blocks.values(), [index_x, index_z, index_y], columns=['one_by_two_10space'])
# Out:
# 5700

# %%
#pandasblocks.sort_index()
#pandasblocks.sortlevel().unstack()
#indexby_coords = pandasblocks.sortlevel().unstack()
indexby_coords = pandasblocks.sortlevel()
#df = indexby_coords.fillna("")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-538c89ab3fef> in <module>()
#       2 #pandasblocks.sortlevel().unstack()
#       3 #indexby_coords = pandasblocks.sortlevel().unstack()
# ----> 4 indexby_coords = pandasblocks.sortlevel()
#       5 #df = indexby_coords.fillna("")
#
# NameError: name 'pandasblocks' is not defined

# %%
df = indexby_coords.T

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2569c44faf66> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Path Type: Straight Path, 1x2 every 8th block spacing

# %%
one_by_two_8space = []
x_spacing = 8
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, x_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                one_by_two_8space.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in one_by_two_8space]
    zs = [j[1] for j in one_by_two_8space]
    ys = [k[2] for k in one_by_two_8space]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

one_by_two_8space_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}

blocks, one_by_two_8space_absolute_path = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=one_by_two_8space,
    ore_count=one_by_two_8space_ore_filter,
    world=world)

ore_counts = pd.DataFrame([one_by_two_8space_ore_filter], index=['one_by_two_8space'])
one_by_two_8space_efficiency = ore_counts / len(one_by_two_8space_absolute_path) * 100
one_by_two_8space_efficiency
print len(blocks)
## Reset ore_filter before running again
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks = pd.concat([pandasblocks, pd.DataFrame(blocks.values(), [index_x, index_z, index_y], columns=['one_by_two_8space'])], join='outer')
# Out:
# 7317
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8a9608d72e87> in <module>()
#      56 index_y = [i[2] for i in blocks.keys()]
#      57 #pandasblocks['one_by_two_8space'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])
# ---> 58 pandasblocks = pd.concat([pandablocks, pd.DataFrame(blocks.values(), [index_x, index_z, index_y], columns=['one_by_two_8space'])])
#
# NameError: name 'pandablocks' is not defined

# %% [markdown]
# ## the rest need pd.concat

# %% [markdown]
# ### Path Type: Straight Path, 1x2 every 6th block spacing

# %%
one_by_two_6space = []
x_spacing = 6
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, x_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                one_by_two_6space.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in one_by_two_6space]
    zs = [j[1] for j in one_by_two_6space]
    ys = [k[2] for k in one_by_two_6space]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

one_by_two_6space_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}

blocks, one_by_two_6space_absolute_path = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=one_by_two_6space,
    ore_count=one_by_two_6space_ore_filter,
    world=world)

ore_counts = pd.DataFrame([one_by_two_6space_ore_filter], index=['one_by_two_6space'])
one_by_two_6space_efficiency = ore_counts / len(one_by_two_6space_absolute_path) * 100
one_by_two_6space_efficiency
print len(blocks)
## Reset ore_filter before running again
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['one_by_two_6space'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %% [markdown]
# ### Path Type: Straight Path, 1x2 every 4th block spacing

# %%
pandasblocks

# %%
one_by_two_4space = []
x_spacing = 4
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, x_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                one_by_two_4space.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in one_by_two_4space]
    zs = [j[1] for j in one_by_two_4space]
    ys = [k[2] for k in one_by_two_4space]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

one_by_two_4space_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}

blocks, one_by_two_4space_absolute_path = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=one_by_two_4space,
    ore_count=one_by_two_4space_ore_filter,
    world=world)
## Reset ore_filter before running again
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['one_by_two_4space'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

ore_counts = pd.DataFrame([one_by_two_4space_ore_filter], index=['one_by_two_4space'])
one_by_two_4space_efficiency = ore_counts / len(one_by_two_4space_absolute_path) * 100
one_by_two_4space_efficiency
print len(blocks)

# %% [markdown]
# ### Path Type: Straight Path, 1x2 every 3rd block spacing

# %%
straight_path = []
x_spacing = 3
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, x_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                straight_path.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in straight_path]
    zs = [j[1] for j in straight_path]
    ys = [k[2] for k in straight_path]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

one_by_two_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, straight_absolute_path = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=straight_path,
    ore_count=one_by_two_ore_filter,
    world=world)
## Reset ore_filter before running again
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['one_by_two_3space'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

ore_counts = pd.DataFrame([one_by_two_ore_filter], index=['one_by_two_3space'])
one_by_two_efficiency = ore_counts / len(straight_absolute_path) * 100
one_by_two_efficiency
print len(blocks)

# %% [markdown]
# ### Path Type: Branch Leaf: leaf_spacing = 4, branch_spacing = 12

# %%
branch_leaf = []
leaf_spacing = 4
branch_spacing = 12
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, branch_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                branch_leaf.append((x,z,y))
    ### leaves
        for z in xrange(3, 48, leaf_spacing): 
            for x_2 in xrange(x, x + 6): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_2,z,y))
            for x_3 in xrange(x - 5, x): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in branch_leaf]
    zs = [j[1] for j in branch_leaf]
    ys = [k[2] for k in branch_leaf]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

branch_leaf_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, branch_leaf = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=branch_leaf,
    ore_count=branch_leaf_ore_filter,
    world=world)
ore_counts = pd.DataFrame([branch_leaf_ore_filter], index=['branch_leaf lf_space=4 br_space=12'])
branch_leaf_efficiency = ore_counts / len(branch_leaf) * 100
branch_leaf_efficiency
print len(blocks)
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['branch_leaf lf_space=4 br_space=12'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %% [markdown]
# ### Path Type: Branch Leaf: leaf_spacing = 3, branch_spacing = 12

# %%
branch_leaf = []
leaf_spacing = 3
branch_spacing = 12
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, branch_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                branch_leaf.append((x,z,y))
    ### leaves
        for z in xrange(3, 48, leaf_spacing): 
            for x_2 in xrange(x, x + 6): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_2,z,y))
            for x_3 in xrange(x - 5, x): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in branch_leaf]
    zs = [j[1] for j in branch_leaf]
    ys = [k[2] for k in branch_leaf]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

branch_leaf_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, branch_leaf = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=branch_leaf,
    ore_count=branch_leaf_ore_filter,
    world=world)

ore_counts = pd.DataFrame([branch_leaf_ore_filter], index=['branch_leaf lf_space=3 br_space=12'])
branch_leaf_lf3_br12_efficiency = ore_counts / len(branch_leaf) * 100
branch_leaf_lf3_br12_efficiency
print len(blocks)
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['branch_leaf lf_space=3 br_space=12'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %% [markdown]
# ### Path Type: Branch Leaf: leaf_spacing = 5, branch spacing = 12

# %%
branch_leaf = []
leaf_spacing = 5
branch_spacing = 12
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, branch_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                branch_leaf.append((x,z,y))
    ### leaves
        for z in xrange(3, 48, leaf_spacing): 
            for x_2 in xrange(x, x + 6): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_2,z,y))
            for x_3 in xrange(x - 5, x): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in branch_leaf]
    zs = [j[1] for j in branch_leaf]
    ys = [k[2] for k in branch_leaf]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

branch_leaf_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, branch_leaf = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=branch_leaf,
    ore_count=branch_leaf_ore_filter,
    world=world)

ore_counts = pd.DataFrame([branch_leaf_ore_filter], index=['branch_leaf lf_space=5 br_space=12'])
branch_leaf_lf5_br12_efficiency = ore_counts / len(branch_leaf) * 100
branch_leaf_lf5_br12_efficiency
print len(blocks)
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['branch_leaf lf_space=5 br_space=12'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %% [markdown]
# ### Path Type: Branch Leaf: leaf_spacing = 6, branch_spacing = 12

# %%
branch_leaf = []
leaf_spacing = 6
branch_spacing = 12
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, branch_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                branch_leaf.append((x,z,y))
    ### leaves
        for z in xrange(3, 48, leaf_spacing): 
            for x_2 in xrange(x, x + 6): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_2,z,y))
            for x_3 in xrange(x - 5, x): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in branch_leaf]
    zs = [j[1] for j in branch_leaf]
    ys = [k[2] for k in branch_leaf]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

branch_leaf_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, branch_leaf = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=branch_leaf,
    ore_count=branch_leaf_ore_filter,
    world=world)

ore_counts = pd.DataFrame([branch_leaf_ore_filter], index=['branch_leaf lf_space=6 br_space=12'])
branch_leaf_lf6_br12_efficiency = ore_counts / len(branch_leaf) * 100
branch_leaf_lf6_br12_efficiency
print len(blocks)
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['branch_leaf lf_space=6 br_space=12'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %% [markdown]
# ### Path Type: Branch Leaf: leaf_spacing = 7, branch_spacing = 12

# %%
branch_leaf = []
leaf_spacing = 7
branch_spacing = 12
for y_pattern in xrange(0, 4, 3): 
    for x in xrange(6, 42, branch_spacing):
        for z in xrange(2, 48):
            for y in range(6 + y_pattern,8 + y_pattern):
                branch_leaf.append((x,z,y))
    ### leaves
        for z in xrange(3, 48, leaf_spacing): 
            for x_2 in xrange(x, x + 6): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_2,z,y))
            for x_3 in xrange(x - 5, x): 
                for y in range(7 + y_pattern,8 + y_pattern):
                    branch_leaf.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in branch_leaf]
    zs = [j[1] for j in branch_leaf]
    ys = [k[2] for k in branch_leaf]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 17])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

branch_leaf_ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}
blocks, branch_leaf = block_handler.simulation(
    x1=-15,
    x2=15,
    z1=-15,
    z2=15,
    y1=0,
    y2=1,
    relative_path=branch_leaf,
    ore_count=branch_leaf_ore_filter,
    world=world)

ore_counts = pd.DataFrame([branch_leaf_ore_filter], index=['branch_leaf lf_space=7 br_space=12'])
branch_leaf_lf7_br12_efficiency = ore_counts / len(branch_leaf) * 100
branch_leaf_lf7_br12_efficiency
index_x = [i[0] for i in blocks.keys()]
index_z = [i[1] for i in blocks.keys()]
index_y = [i[2] for i in blocks.keys()]
pandasblocks['branch_leaf lf_space=7 br_space=12'] = pd.DataFrame(blocks.values(), [index_x, index_z, index_y])

# %%
#with open('minedores', 'w') as f:
#    f.write(pandasblocks.to_csv())
#pandasblocks
#f.closed

# %%
#df = pd.read_csv("minedores")

# %% [markdown]
# ### Comparison of Paths' Performance

# %%
all_efficiencies = pd.concat([branch_leaf_lf3_br12_efficiency,
                    branch_leaf_efficiency, 
                    branch_leaf_lf5_br12_efficiency,
                    branch_leaf_lf6_br12_efficiency,
                    branch_leaf_lf7_br12_efficiency,
                    one_by_two_efficiency, 
                    one_by_two_4space_efficiency,
                             ])
all_efficiencies

# %%
branch_leaf_efficiencies = pd.concat([branch_leaf_lf3_br12_efficiency,
                    branch_leaf_efficiency, 
                    branch_leaf_lf5_br12_efficiency,
                    branch_leaf_lf6_br12_efficiency,
                    branch_leaf_lf7_br12_efficiency,
                    ])
branch_leaf_efficiencies

# %%
branch_leaf_efficiencies.sort().T.plot(kind='bar', title="Branch_Leaf_Mining_Efficiencies", figsize=(10,7))

# %%
one_by_two_efficiencies = pd.concat([one_by_two_efficiency, 
                    one_by_two_4space_efficiency,
                    one_by_two_6space_efficiency,
                    one_by_two_8space_efficiency,
                    one_by_two_10space_efficiency,])
one_by_two_efficiencies

# %%
one_by_two_efficiencies.sort().T.plot(kind='bar', title="1 x 2 spacing optimization", figsize=(10,7))

# %% [markdown]
# ### Compare the Two Top Performers for Diamonds

# %%
top_diamond_performers = pd.concat([branch_leaf_efficiency, one_by_two_efficiency])
top_diamond_performers.diamond.plot(kind='bar', title='Diamonds', grid=True)
top_diamond_performers.T.plot(kind='bar')

# %% [markdown]
# ##### Send to plot.ly

# %%
top_diamond_performers.T.index.tolist()

# %%
branch_leaf_data = top_diamond_performers.T['branch_leaf lf_space=4 br_space=12'].tolist()
one_by_two = top_diamond_performers.T['one_by_two_3space'].tolist()

# %%
trace1 = Bar(
    x=top_diamond_performers.T.index.tolist(),
    y=branch_leaf_data,
    name='branch_leaf'
)

trace2 = Bar(
    x=top_diamond_performers.T.index.tolist(),
    y=one_by_two,
    name='one_by_two'
)

data = Data([trace1, trace2])
layout = Layout(
    barmode='group'
)
fig = Figure(data=data, layout=layout)
plot_url = py.plot(fig, filename='test1234')
