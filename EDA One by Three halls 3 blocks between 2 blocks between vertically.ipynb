# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
import block_handler
import plot_chunk

# %% [markdown]
# #  Minepath Eval

# %% [markdown]
# ### Path Type: Straight Path

# %%
relative_path = []
for y_pattern in xrange(0, 7, 4): 
    for x in xrange(6, 42, 4):
        for z in xrange(2, 48):
            for y in range(5 + y_pattern,8 + y_pattern):
                relative_path.append((x,z,y))
#        for z in xrange(3, 48, 3): 
#            for x_2 in xrange(x, x + 6): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_2,z,y))
#            for x_3 in xrange(x - 5, x): 
#                for y in range(6 + y_pattern,7 + y_pattern):
#                    relative_path.append((x_3,z,y))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

try:
    xs = [i[0] for i in relative_path]
    zs = [j[1] for j in relative_path]
    ys = [k[2] for k in relative_path]
    ax.scatter(xs, zs, ys, color='green', marker='|')
    ax.set_zlim3d([0, 33])
    ax.set_xlabel('X Label')
    ax.set_ylabel('Z Label')
    ax.set_zlabel('Y Label')
except KeyError:
    pass

# %% [markdown]
# #### Variables

# %%
ore_filter = {
    'iron':0,
    'diamond':0,
    'redstone':0,
#    'coal':0,
    'gold':0,
}

world = block_handler.load_world('/Users/ryanlambert/minecraft-server/world')

# %%
blocks, absolute_path = block_handler.simulation(
    x1=-10,
    x2=10,
    z1=-10,
    z2=10,
    y1=0,
    y2=1,
    relative_path=relative_path,
    ore_count=ore_filter,
    world=world)

# %%
total_blocks_mined = len(blocks.keys()) + len(absolute_path)

# %%
ore_counts = pd.DataFrame([ore_filter])

# %% [markdown]
# ### Efficiencies for this path

# %%
ore_counts / total_blocks_mined * 100
# Out:
#     diamond    gold      iron  redstone
# 0  0.425679  0.4226  2.338542  3.120622

# %%
ore_counts
# Out:
#    diamond  gold  iron  redstone
# 0      553   549  3038      4054
